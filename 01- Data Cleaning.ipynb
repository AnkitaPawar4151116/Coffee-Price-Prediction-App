# %%
#importing libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
ds= pd.read_csv('messy_coffee_data (1).csv')
print(ds.to_string())
# Out:
#         Size Coffee_Type Milk_Type    Flavor  Shots         Temperature Cup_Quality       Price
# 0      Small    Liberica     Whole   Caramel    2.0             unknown           2   13.784431
# 1      Large     Arabica       NaN   Caramel    2.0   66.62073098517166           5   16.029589
# 2      Small     Arabica       NaN       NaN    3.0   79.45691105806996           1   11.810101
# 3     Medium     Arabica       Soy  Hazelnut    2.0   60.77777682897872           1   11.410164
# 4     Medium     Arabica       Soy  Hazelnut    3.0   85.44687397658547           3   16.316949
# 5      Large     Robusta     Whole       NaN    2.0   88.53128917427367           1   13.544010
# 6      Small    Liberica       NaN   Vanilla    1.0   79.86370321905864           2   12.417722
# 7      Small    Liberica    Almond  Hazelnut    NaN   75.38008959528007           5   17.052462
# 8      Large     Arabica       Soy   Caramel    3.0   81.77193268089214           3   16.285402
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2150 entries, 0 to 2149
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         1929 non-null   object
#  1   Coffee_Type  2150 non-null   object
#  2   Milk_Type    1439 non-null   object
#  3   Flavor       1588 non-null   object
#  4   Shots        2040 non-null   float64
#  5   Temperature  2150 non-null   object
#  6   Cup_Quality  2150 non-null   object
#  7   Price        2150 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 134.5+ KB

# %%
ds['Size'].unique()
# Out:
# array(['Small', 'Large', 'Medium', nan], dtype=object)

# %%
ds.dropna()
# Out:
#         Size Coffee_Type Milk_Type    Flavor  Shots        Temperature  \
# 0      Small    Liberica     Whole   Caramel    2.0            unknown
# 3     Medium     Arabica       Soy  Hazelnut    2.0  60.77777682897872
# 4     Medium     Arabica       Soy  Hazelnut    3.0  85.44687397658547
# 8      Large     Arabica       Soy   Caramel    3.0  81.77193268089214
# 9      Small     Arabica    Almond   Vanilla    2.0  69.79083864673851
# ...      ...         ...       ...       ...    ...                ...
# 2138   Small     Arabica       Soy  Hazelnut    1.0  68.76024148411369
# 2139  Medium     Arabica     Whole     Mocha    1.0  75.35512092443305
# 2143  Medium     Arabica     Whole   Vanilla    3.0  86.44551771940888
# 2144   Large    Liberica       Soy   Vanilla    1.0            unknown
# 2148  Medium     Arabica       Soy   Vanilla    3.0  69.09637410668711
#
#      Cup_Quality      Price
# 0              2  13.784431
# 3              1  11.410164
# ...

# %%
ds.duplicated().sum()
# Out:
# np.int64(144)

# %%
ds.drop_duplicates(inplace=True)

# %%
ds['Coffee_Type'].unique()
# Out:
# array(['Liberica', 'Arabica', 'Robusta'], dtype=object)

# %%
ds['Milk_Type'].unique()
# Out:
# array(['Whole', nan, 'Soy', 'Almond'], dtype=object)

# %%
#print(ds.to_string())

# %%
ds['Temperature'].replace({'unknown':np.nan},inplace=True)

# %%
ds['Cup_Quality'].replace({'bad':np.nan},inplace=True)

# %%
ds.dropna(inplace=True)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 776 entries, 3 to 2126
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         776 non-null    object
#  1   Coffee_Type  776 non-null    object
#  2   Milk_Type    776 non-null    object
#  3   Flavor       776 non-null    object
#  4   Shots        776 non-null    float64
#  5   Temperature  776 non-null    object
#  6   Cup_Quality  776 non-null    object
#  7   Price        776 non-null    float64
# dtypes: float64(2), object(6)
# memory usage: 54.6+ KB

# %%
ds.columns
# Out:
# Index(['Size', 'Coffee_Type', 'Milk_Type', 'Flavor', 'Shots', 'Temperature',
#        'Cup_Quality', 'Price'],
#       dtype='object')

# %%
ds['Size'].unique()
# Out:
# array(['Medium', 'Large', 'Small'], dtype=object)

# %%
ds['Coffee_Type'].unique()
# Out:
# array(['Arabica', 'Robusta', 'Liberica'], dtype=object)

# %%
ds['Milk_Type'].unique()
# Out:
# array(['Soy', 'Almond', 'Whole'], dtype=object)

# %%
ds['Flavor'].unique()
# Out:
# array(['Hazelnut', 'Caramel', 'Vanilla', 'Mocha'], dtype=object)

# %%
ds['Shots'].unique()
# Out:
# array([2., 3., 1.])

# %%
ds['Temperature'].unique()
# Out:
# array(['60.77777682897872', '85.44687397658547', '81.77193268089214',
#        '69.79083864673851', '64.28042344443563', '81.4841453314292',
#        '61.27292211745934', '79.49628087694559', '80.49997937083793',
#        '72.57348651806517', '72.64396345347927', '68.5901832766437',
#        '65.43187058768818', '72.64588094541082', '70.89529502448288',
#        '65.0720118349384', '62.49812643924222', '85.7423377027979',
#        '68.42442093626738', '78.73181389319686', '64.89385118978966',
#        '81.8665112301656', '89.32365805004883', '83.50266904716317',
#        '65.31435101787633', '61.66819542560371', '85.51076542062793',
#        '76.9875260361602', '68.47281799028025', '74.83901589059754',
#        '61.90570192517925', '82.0878830333292', '67.28465565033702',
#        '71.39730482668666', '60.22195584577138', '70.45702520042187',
#        '78.22307462685494', '72.25646197426994', '82.9763837504957',
#        '66.89605903120108', '87.60154520650467', '65.05892293635488',
# ...

# %%
ds['Cup_Quality'].unique()
# Out:
# array(['1', '3', '2', '4', '5'], dtype=object)

# %%
print(ds.to_string())
# Out:
#         Size Coffee_Type Milk_Type    Flavor  Shots         Temperature Cup_Quality       Price
# 3     Medium     Arabica       Soy  Hazelnut    2.0   60.77777682897872           1   11.410164
# 4     Medium     Arabica       Soy  Hazelnut    3.0   85.44687397658547           3   16.316949
# 8      Large     Arabica       Soy   Caramel    3.0   81.77193268089214           3   16.285402
# 9      Small     Arabica    Almond   Vanilla    2.0   69.79083864673851           2   12.604810
# 12    Medium     Robusta     Whole   Vanilla    3.0   64.28042344443563           2   12.403574
# 14    Medium    Liberica     Whole     Mocha    2.0    81.4841453314292           4   16.410568
# 18     Small     Arabica    Almond   Vanilla    1.0   61.27292211745934           1    9.992140
# 19     Large     Robusta    Almond  Hazelnut    1.0   79.49628087694559           2   14.438774
# 22    Medium     Robusta     Whole   Caramel    1.0   80.49997937083793           1   12.176314
# ...

# %%
ds['Price'].unique()
# Out:
# array([ 11.41016364,  16.31694943,  16.2854018 ,  12.60481007,
#         12.40357422,  16.41056802,   9.99213967,  14.43877391,
#         12.17631378,  16.76630629,  12.63500573,  15.30572847,
#         14.53468455,  13.58097773,  11.7208478 ,  16.10219855,
#         12.48984165,  16.46807037,  13.4837498 ,  17.82865268,
#         12.73272264,  15.81441607,  14.77104085,  16.51876411,
#         11.57091755,  14.20182311,  18.51566299,  15.61266217,
#         12.13450482,  13.63508446,  15.31363884,  17.80210747,
#         15.16046323,  17.58518826,  12.86724355,  11.7730338 ,
#         14.00464188,  16.6175282 ,  16.99997329,  16.66377195,
#         14.83283239,  15.97117147,  15.71139865,  16.34586608,
#        999.        ,  15.1356763 ,  13.621117  ,  15.234136  ,
#         16.26632551,  11.49273444,  15.57529776,  16.79629485,
#         18.33064727,  18.79651583,  17.57225394,  14.40443773,
#         11.02121582,  17.17481935,  14.75934253,  15.17272696,
# ...

# %%
ds= ds[ds['Price'] < 50]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 767 entries, 3 to 2091
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         767 non-null    object
#  1   Coffee_Type  767 non-null    object
#  2   Milk_Type    767 non-null    object
#  3   Flavor       767 non-null    object
#  4   Shots        767 non-null    float64
#  5   Temperature  767 non-null    object
#  6   Cup_Quality  767 non-null    object
#  7   Price        767 non-null    float64
# dtypes: float64(2), object(6)
# memory usage: 53.9+ KB

# %%
ds['Temperature'] = pd.to_numeric(ds['Temperature'])

# %%
ds['Cup_Quality']=pd.to_numeric(ds['Cup_Quality'])

# %%
ds= ds.to_csv('cleand_coffee_data.csv')
